# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
from matplotlib import pyplot as plt

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y1',  #plot and label. label is seen in legend
         color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2',  #legend
         color='blue', linestyle='dotted')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) #how dark the grids are, where the smaller the nummber the fainter the grids (0.xx)
plt.legend(loc='upper left') #loc refers to the legend

# %% [markdown]
# ### Things to note

# %%
#c =colour, linestyle = ls, linewidth = lw

# %%
#there will be output even without plt.show() because jupyter is interactive.

# %%
plt.plot(x, y_1, y_2)

#the same as
# Out:
# [<matplotlib.lines.Line2D at 0x2638a88c170>,
#  <matplotlib.lines.Line2D at 0x2638a88c140>]

# %%
plt.plot(x, y_1,),
         
plt.plot(x, y_2,),
# Out:
# ([<matplotlib.lines.Line2D at 0x2638a9d9c70>],)

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75 #require this  to define the error

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error, #define xerr=x_error etc
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %%
#Alas, our plot does not look good because sinx lies between 1 and -1 but x2 has no such bounds. One way to fix this is to add another y-axis that shares the same x-axis.

# %% [markdown]
# ## We need another axis!

# %%
#twinx() is used to plot another axis
# 2 legends to plit for different axis

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %%
#our plot still does not look good because we have only a few points. use np.linspace to fix this with:
x = np.linspace(0, 6, 100) #change x values
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# # 3 Saving to disc

# %%
plt.savefig('simple-plot.png', dpi=150)

#savefig() saves the plot, dpi specifies the resolution
#When you run this code, you will find the file saved in the same directory (folder) 
#as the one in your notebook lives in. If you want it saved elsewhere, 
#specify the path in more detail.

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])

plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey') 
#hlines() needs the y value and the range of x
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 data = np.loadtxt('Complete_TAVG_daily.txt',
#       2                    skiprows=24)
#       3 date = data[:, 0]
#       4 anomaly = data[:, -1]
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1378 if isinstance(delimiter, bytes):
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
#    1383             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1384             max_rows=max_rows, quote=quotechar)
#    1386 return arr
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:997, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     995     fname = os.fspath(fname)
#     996 if isinstance(fname, str):
# --> 997     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     998     if encoding is None:
#     999         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: Complete_TAVG_daily.txt not found.

# %%
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 3
#       1 plt.style.use('fivethirtyeight')
# ----> 3 data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
#       5 date = data[:, 0]
#       6 anomaly = data[:, -1]
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1378 if isinstance(delimiter, bytes):
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
#    1383             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1384             max_rows=max_rows, quote=quotechar)
#    1386 return arr
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:997, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     995     fname = os.fspath(fname)
#     996 if isinstance(fname, str):
# --> 997     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     998     if encoding is None:
#     999         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: Complete_TAVG_daily.txt not found.

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
plt.style.use('fivethirtyeight')
#included at the top

# %%
#just run plt.xkcd() instead of setting a style. Here is what the previous plot looks like using the xkcd style
plt.xkcd()

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')
