# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## **Exercise 1** ##

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# File ~\miniconda3\Lib\site-packages\ipykernel\iostream.py:683, in OutStream.write(self, string)
#     681 is_child = not self._is_master_process()
#     682 # only touch the buffer in the IO thread to avoid races
# --> 683 with self._buffer_lock:
#     684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Exercise 2** ##

# %%
print = 'PRINT' #this assigns the function print to a string called PRINT

# %%
print('Hello World') #this confuses the system because PRINT('Hello World') does not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print('Hello World') #this confuses the system because PRINT('Hello World') does not work
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## **Exercise 3** ##

# %%
print('squares = [i**2 for i in range(10)]')
# Out:
# squares = [i**2 for i in range(10)]

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# Out:
# 476 ns ± 8.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# The above code means that the average time taken to run the code is 476ns with a standard deviation of 8.4ns per loop.
# The code ran for 7 runs, each with a million loops

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 615 ns ± 5.39 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# The above code means that the average time taken to run the code is 615ns with a standard deviation of 5.39ns per loop.
# The code ran for 7 runs, each with a million loops
